# %%
# Python3 program to create target string, starting from 
# random string using Genetic Algorithm 
# Author Atul Kumar on https://www.geeksforgeeks.org/genetic-algorithms/

import random 

# Number of individuals in each generation 
POPULATION_SIZE = 100

# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated 
TARGET = "To be or not to be."

class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness() 

    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 

    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 

    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''

        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):	 

            # random probability 
            prob = random.random() 

            # if prob is less than 0.45, insert gene 
            # from parent 1 
            if prob < 0.45: 
                child_chromosome.append(gp1) 

            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 

            # otherwise insert random gene(mutate), 
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 

        # create new Individual(offspring) using 
        # generated chromosome for offspring 
        return Individual(child_chromosome) 

    def cal_fitness(self): 
        ''' 
        Calculate fittness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 

# Driver code 
def main(): 
    global POPULATION_SIZE 

    #current generation 
    generation = 1

    found = False
    population = [] 

    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 

    while not found: 

        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 

        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break

        # Otherwise generate new offsprings for new generation 
        new_generation = [] 

        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 

        # From 50% of fittest population, Individuals 
        # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 

        population = new_generation 

        print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

        generation += 1


    print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String: BM6GYvXr n!)t86 JJD	Fitness: 15
# Generation: 2	String: BM6GYvXr n!)t86 JJD	Fitness: 15
# Generation: 3	String: BM6GYvXr n!)t86 JJD	Fitness: 15
# Generation: 4	String: BM6GYvXr n!)t86 JJD	Fitness: 15
# Generation: 5	String: BM6GYvXr n!)t86 JJD	Fitness: 15
# Generation: 6	String: H9 _t arqakN 6o 4)w	Fitness: 13
# Generation: 7	String: H9 _e lr ?J
#  6o m)(	Fitness: 11
# Generation: 8	String: H9 _e lr ?J
#  6o m)(	Fitness: 11
# Generation: 9	String: H9 _e lr ?J
#  6o m)(	Fitness: 11
# Generation: 10	String: H9 _e lr ?J
#  6o m)(	Fitness: 11
# Generation: 11	String: 59 be .r GEN /o 1}(	Fitness: 10
# Generation: 12	String: T6 _epor no}fPo m}(	Fitness: 9
# Generation: 13	String: T6 _epor no}fPo m}(	Fitness: 9
# Generation: 14	String: T6 _v or no5 uo m}(	Fitness: 8
# Generation: 15	String: T6 _v or no5 uo m}(	Fitness: 8
# Generation: 16	String: T6 _v or no5 uo m}(	Fitness: 8
# Generation: 17	String: Te be or no
#  uozGtL	Fitness: 7
# Generation: 18	String: Te be or no
#  uozGtL	Fitness: 7
# Generation: 19	String: T_ be or no
#  uo  (L	Fitness: 6
# Generation: 20	String: T_ be or no
#  uo  (L	Fitness: 6
# Generation: 21	String: T_ be or no
#  uo  (L	Fitness: 6
# Generation: 22	String: T_ be or no
#  uo  (L	Fitness: 6
# Generation: 23	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 24	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 25	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 26	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 27	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 28	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 29	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 30	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 31	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 32	String: T% be or noH uo zQ.	Fitness: 5
# Generation: 33	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 34	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 35	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 36	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 37	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 38	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 39	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 40	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 41	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 42	String: Te be or noK ao ?e.	Fitness: 4
# Generation: 43	String: TF be or no# tI be.	Fitness: 3
# Generation: 44	String: TF be or no# tI be.	Fitness: 3
# Generation: 45	String: TF be or no# tI be.	Fitness: 3
# Generation: 46	String: TF be or no# tI be.	Fitness: 3
# Generation: 47	String: TF be or no# tI be.	Fitness: 3
# Generation: 48	String: TF be or no# tI be.	Fitness: 3
# Generation: 49	String: TF be or no# tI be.	Fitness: 3
# Generation: 50	String: TF be or no# tI be.	Fitness: 3
# Generation: 51	String: TW be or noi to be.	Fitness: 2
# Generation: 52	String: TW be or noi to be.	Fitness: 2
# Generation: 53	String: TW be or noi to be.	Fitness: 2
# Generation: 54	String: TW be or noi to be.	Fitness: 2
# Generation: 55	String: TW be or noi to be.	Fitness: 2
# Generation: 56	String: TW be or noi to be.	Fitness: 2
# Generation: 57	String: TW be or noi to be.	Fitness: 2
# Generation: 58	String: TW be or noi to be.	Fitness: 2
# Generation: 59	String: TW be or noi to be.	Fitness: 2
# Generation: 60	String: TW be or noi to be.	Fitness: 2
# Generation: 61	String: TW be or noi to be.	Fitness: 2
# Generation: 62	String: TW be or noi to be.	Fitness: 2
# Generation: 63	String: TW be or noi to be.	Fitness: 2
# Generation: 64	String: T; be or not to be.	Fitness: 1
# Generation: 65	String: T; be or not to be.	Fitness: 1
# Generation: 66	String: T; be or not to be.	Fitness: 1
# Generation: 67	String: T; be or not to be.	Fitness: 1
# Generation: 68	String: T; be or not to be.	Fitness: 1
# Generation: 69	String: T; be or not to be.	Fitness: 1
# Generation: 70	String: T; be or not to be.	Fitness: 1
# Generation: 71	String: T; be or not to be.	Fitness: 1
# Generation: 72	String: T; be or not to be.	Fitness: 1
# Generation: 73	String: T; be or not to be.	Fitness: 1
# Generation: 74	String: T; be or not to be.	Fitness: 1
# Generation: 75	String: T; be or not to be.	Fitness: 1
# Generation: 76	String: T; be or not to be.	Fitness: 1
# Generation: 77	String: T; be or not to be.	Fitness: 1
# Generation: 78	String: T; be or not to be.	Fitness: 1
# Generation: 79	String: T; be or not to be.	Fitness: 1
# Generation: 80	String: T; be or not to be.	Fitness: 1
# Generation: 81	String: T; be or not to be.	Fitness: 1
# Generation: 82	String: T; be or not to be.	Fitness: 1
# Generation: 83	String: T; be or not to be.	Fitness: 1
# Generation: 84	String: T; be or not to be.	Fitness: 1
# Generation: 85	String: T; be or not to be.	Fitness: 1
# Generation: 86	String: T; be or not to be.	Fitness: 1
# Generation: 87	String: T; be or not to be.	Fitness: 1
# Generation: 88	String: T; be or not to be.	Fitness: 1
# Generation: 89	String: T; be or not to be.	Fitness: 1
# Generation: 90	String: T; be or not to be.	Fitness: 1
# Generation: 91	String: T; be or not to be.	Fitness: 1
# Generation: 92	String: T; be or not to be.	Fitness: 1
# Generation: 93	String: T; be or not to be.	Fitness: 1
# Generation: 94	String: T; be or not to be.	Fitness: 1
# Generation: 95	String: T; be or not to be.	Fitness: 1
# Generation: 96	String: T; be or not to be.	Fitness: 1
# Generation: 97	String: T; be or not to be.	Fitness: 1
# Generation: 98	String: T; be or not to be.	Fitness: 1
# Generation: 99	String: T; be or not to be.	Fitness: 1
# Generation: 100	String: T; be or not to be.	Fitness: 1
# Generation: 101	String: To be or not to be.	Fitness: 0
